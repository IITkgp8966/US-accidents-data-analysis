# %% [markdown]
# ## EDA-for-us-accidents
#
# Use the "Run" button to execute the code.

# %% [markdown]
#    The filename of the dataset has been updated, the new filename is'/content/us-accidents/US_Accidents_Dec21_updated.csv'

# %% [markdown]
#  The "Source" column is removed from the updated dataset.

# %% [markdown]
#  -informaiton about accidents

# %% [markdown]
# can use useful to prevent accidents

# %% [markdown]
# mention that this does not contain data about New York

# %%
! pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od

download_data_link ='https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents'

od.download(download_data_link)
# Out:
# Skipping, found downloaded files in "./us-accidents" (use force=True to force download)

# %%
data_filename ='/content/us-accidents/US_Accidents_Dec21_updated.csv'

# %% [markdown]
# ## Data Preparation and Cleaning

# %% [markdown]
# 1.Load the file using Pandas

# %% [markdown]
# 2.Look at some information about the data & the columns

# %% [markdown]
# 3.Fix any missing or incorrect values

# %%
import pandas as pd 

df = pd.read_csv('/content/us-accidents/US_Accidents_Dec21_updated.csv')

# %%
df
# Out:
#                 ID  Severity           Start_Time             End_Time  \
# 0              A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08
# 1              A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20
# 2              A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39
# 3              A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45
# 4              A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43
# ...            ...       ...                  ...                  ...
# 2845337  A-2845338         2  2019-08-23 18:03:25  2019-08-23 18:32:01
# 2845338  A-2845339         2  2019-08-23 19:11:30  2019-08-23 19:38:23
# 2845339  A-2845340         2  2019-08-23 19:00:21  2019-08-23 19:28:49
# 2845340  A-2845341         2  2019-08-23 19:00:21  2019-08-23 19:29:42
# 2845341  A-2845342         2  2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %%
len(df.columns)
# Out:
# 47

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711439e+01
# std    4.787216e-01  5.363797e+00  1.831782e+01  5.363873e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609799e+01 -9.241772e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845342e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026779e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 14

# %% [markdown]
# find missing value

# %%
df.isna().sum()
# Out:
# ID                             0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                        0
# End_Lng                        0
# Distance(mi)                   0
# Description                    0
# Number                   1743911
# Street                         2
# Side                           0
# City                         137
# County                         0
# State                          0
# Zipcode                     1319
# Country                        0
# Timezone                    3659
# Airport_Code                9549
# Weather_Timestamp          50736
# Temperature(F)             69274
# Wind_Chill(F)             469643
# Humidity(%)                73092
# Pressure(in)               59200
# Visibility(mi)             70546
# Wind_Direction             73775
# Wind_Speed(mph)           157944
# ...

# %% [markdown]
# find missing values in columns in terms of percentage per columns

# %%
missing_percentages=df.isna().sum().sort_values(ascending=False)/len(df)
missing_percentages
# Out:
# Number                   6.129003e-01
# Precipitation(in)        1.931079e-01
# Wind_Chill(F)            1.650568e-01
# Wind_Speed(mph)          5.550967e-02
# Wind_Direction           2.592834e-02
# Humidity(%)              2.568830e-02
# Weather_Condition        2.482514e-02
# Visibility(mi)           2.479350e-02
# Temperature(F)           2.434646e-02
# Pressure(in)             2.080593e-02
# Weather_Timestamp        1.783125e-02
# Airport_Code             3.356011e-03
# Timezone                 1.285961e-03
# Nautical_Twilight        1.007612e-03
# Civil_Twilight           1.007612e-03
# Sunrise_Sunset           1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.635647e-04
# City                     4.814887e-05
# Street                   7.029032e-07
# Country                  0.000000e+00
# Junction                 0.000000e+00
# Start_Time               0.000000e+00
# End_Time                 0.000000e+00
# Start_Lat                0.000000e+00
# ...

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages.plot(kind='bar')

# %%
missing_percentages.plot(kind='barh')

# %%
missing_percentages[missing_percentages!=0]
# Out:
# Number                   6.129003e-01
# Precipitation(in)        1.931079e-01
# Wind_Chill(F)            1.650568e-01
# Wind_Speed(mph)          5.550967e-02
# Wind_Direction           2.592834e-02
# Humidity(%)              2.568830e-02
# Weather_Condition        2.482514e-02
# Visibility(mi)           2.479350e-02
# Temperature(F)           2.434646e-02
# Pressure(in)             2.080593e-02
# Weather_Timestamp        1.783125e-02
# Airport_Code             3.356011e-03
# Timezone                 1.285961e-03
# Nautical_Twilight        1.007612e-03
# Civil_Twilight           1.007612e-03
# Sunrise_Sunset           1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.635647e-04
# City                     4.814887e-05
# Street                   7.029032e-07
# dtype: float64

# %%
missing_percentages[missing_percentages!=0].plot(kind='barh')

# %% [markdown]
# ### Exploratory Analysis and Visualization

# %% [markdown]
# Columns we'll analyze:

# %% [markdown]
#   1.City

# %% [markdown]
# 2.Start Time

# %% [markdown]
# 3.Start Lat, Start Lng

# %% [markdown]
# 4.Temperature

# %% [markdown]
# 5.Weather Condition

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.City
# Out:
# 0               Dublin
# 1               Dayton
# 2           Cincinnati
# 3                Akron
# 4           Cincinnati
#               ...
# 2845337      Riverside
# 2845338      San Diego
# 2845339         Orange
# 2845340    Culver City
# 2845341       Highland
# Name: City, Length: 2845342, dtype: object

# %%
cities = df.City.unique()
len(cities)
# Out:
# 11682

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# Miami                           106966
# Los Angeles                      68956
# Orlando                          54691
# Dallas                           41979
# Houston                          39448
#                                  ...
# Ridgedale                            1
# Sekiu                                1
# Wooldridge                           1
# Bullock                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 11681, dtype: int64

# %%
cities_by_accident[:20]
# Out:
# Miami           106966
# Los Angeles      68956
# Orlando          54691
# Dallas           41979
# Houston          39448
# Charlotte        33152
# Sacramento       32559
# San Diego        26627
# Raleigh          22840
# Minneapolis      22768
# Portland         20944
# Nashville        20267
# Austin           18301
# Baton Rouge      18182
# Phoenix          17143
# Saint Paul       16869
# New Orleans      16251
# Atlanta          15622
# Jacksonville     14967
# Richmond         14349
# Name: City, dtype: int64

# %% [markdown]
# New York data persent or not check

# %%
'New York' in df.City
# Out:
# False

# %%
cities_by_accident[:20].plot(kind ='barh')

# %% [markdown]
# seaborn import

# %%
import seaborn as sns

sns.set_style("darkgrid")

# %%
sns.distplot(cities_by_accident)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
high_accident_city = cities_by_accident[cities_by_accident>=10000]
low_accident_city = cities_by_accident[cities_by_accident<10000]

# %%
len(high_accident_city)
# Out:
# 34

# %%
len(low_accident_city)
# Out:
# 11647

# %%
len(high_accident_city)/len(cities)
# Out:
# 0.002910460537579182

# %%
sns.distplot(high_accident_city)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(low_accident_city)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(cities_by_accident, log_scale=True)

# %%
cities_by_accident[cities_by_accident==1]
# Out:
# Carney                          1
# Waverly Hall                    1
# Center Sandwich                 1
# Glen Flora                      1
# Sulphur Springs                 1
#                                ..
# Ridgedale                       1
# Sekiu                           1
# Wooldridge                      1
# Bullock                         1
# American Fork-Pleasant Grove    1
# Name: City, Length: 1110, dtype: int64

# %% [markdown]
# ### start time

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.Start_Time
# Out:
# 0         2016-02-08 00:37:08
# 1         2016-02-08 05:56:20
# 2         2016-02-08 06:15:39
# 3         2016-02-08 06:51:45
# 4         2016-02-08 07:53:43
#                   ...
# 2845337   2019-08-23 18:03:25
# 2845338   2019-08-23 19:11:30
# 2845339   2019-08-23 19:00:21
# 2845340   2019-08-23 19:00:21
# 2845341   2019-08-23 18:52:06
# Name: Start_Time, Length: 2845342, dtype: datetime64[ns]

# %%
 df.Start_Time = pd.to_datetime(df.Start_Time)

# %%
df.Start_Time
# Out:
# 0         2016-02-08 00:37:08
# 1         2016-02-08 05:56:20
# 2         2016-02-08 06:15:39
# 3         2016-02-08 06:51:45
# 4         2016-02-08 07:53:43
#                   ...
# 2845337   2019-08-23 18:03:25
# 2845338   2019-08-23 19:11:30
# 2845339   2019-08-23 19:00:21
# 2845340   2019-08-23 19:00:21
# 2845341   2019-08-23 18:52:06
# Name: Start_Time, Length: 2845342, dtype: datetime64[ns]

# %%
df.Start_Time.dt.hour
# Out:
# 0           0
# 1           5
# 2           6
# 3           6
# 4           7
#            ..
# 2845337    18
# 2845338    19
# 2845339    19
# 2845340    19
# 2845341    18
# Name: Start_Time, Length: 2845342, dtype: int64

# %%
sns.histplot(df.Start_Time.dt.hour, bins =24)

# %% [markdown]
# from this plot we see most of the accident happen between 3 PM to 7 PM.

# %% [markdown]
# Secound most accidents happend between 6 AM to 9 AM.

# %%
sns.distplot(df.Start_Time.dt.hour, bins=24, kde=False, norm_hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# most of the accidents happend between 3 PM to 7 pm.

# %%
sns.distplot(df.Start_Time.dt.dayofweek, bins=7, kde=False, norm_hist=True)

# %% [markdown]
# less accident in weekends.may less amout of people go for job also student are not travelling not much.

# %%
sunday_start_time=df.Start_Time[df.Start_Time.dt.dayofweek==6]
sns.distplot(sunday_start_time.dt.hour, bins=24, kde=False, norm_hist=True)

# %% [markdown]
# sunday most of the accident happend in 3 PM to 5 PM.

# %%
monday_start_time=df.Start_Time[df.Start_Time.dt.dayofweek==0]
sns.distplot(monday_start_time.dt.hour, bins=24, kde=False, norm_hist=True)

# %% [markdown]
# on monday most of the accident happend after at the morning time and evening time so may be at the time of job go and come back to home.

# %%
sns.distplot(monday_start_time.dt.month, bins=12, kde=False, norm_hist=True)

# %% [markdown]
# most of the accident happend december may be last month of the year and for new year they want to go for any trip and want to party and all things on 31 th december.

# %%
df_2019=df[df.Start_Time.dt.year==2019]
sns.distplot(df_2019.Start_Time.dt.month, bins=12, kde=False, norm_hist=True)

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# in YEAR 2019 Maximum  accidents happend in december month.

# %%
df
# Out:
#                 ID  Severity          Start_Time             End_Time  \
# 0              A-1         3 2016-02-08 00:37:08  2016-02-08 06:37:08
# 1              A-2         2 2016-02-08 05:56:20  2016-02-08 11:56:20
# 2              A-3         2 2016-02-08 06:15:39  2016-02-08 12:15:39
# 3              A-4         2 2016-02-08 06:51:45  2016-02-08 12:51:45
# 4              A-5         3 2016-02-08 07:53:43  2016-02-08 13:53:43
# ...            ...       ...                 ...                  ...
# 2845337  A-2845338         2 2019-08-23 18:03:25  2019-08-23 18:32:01
# 2845338  A-2845339         2 2019-08-23 19:11:30  2019-08-23 19:38:23
# 2845339  A-2845340         2 2019-08-23 19:00:21  2019-08-23 19:28:49
# 2845340  A-2845341         2 2019-08-23 19:00:21  2019-08-23 19:29:42
# 2845341  A-2845342         2 2019-08-23 18:52:06  2019-08-23 19:21:31
#
#          Start_Lat   Start_Lng    End_Lat     End_Lng  Distance(mi)  \
# ...

# %% [markdown]
# ### start latitude and longitude

# %%
df.Start_Lat
# Out:
# 0          40.108910
# 1          39.865420
# 2          39.102660
# 3          41.062130
# 4          39.172393
#              ...
# 2845337    34.002480
# 2845338    32.766960
# 2845339    33.775450
# 2845340    33.992460
# 2845341    34.133930
# Name: Start_Lat, Length: 2845342, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -83.092860
# 1          -84.062800
# 2          -84.524680
# 3          -81.537840
# 4          -84.492792
#               ...
# 2845337   -117.379360
# 2845338   -117.148060
# 2845339   -117.847790
# 2845340   -118.403020
# 2845341   -117.230920
# Name: Start_Lng, Length: 2845342, dtype: float64

# %%
sns.scatterplot(x=df.Start_Lng,y=df.Start_Lat)

# %% [markdown]
# US Accidents EDA analysis

# %%
import folium

# %%
lat, lon = df.Start_Lat[0], df.Start_Lng[0]
lat, lon
# Out:
# (40.10891, -83.09286)

# %%
Map=folium.Map()
marker = folium.Marker((lat, lon ))
marker.add_to(Map)
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from folium.plugins import HeatMap

# %%
sample_df = df.sample(int(0.001 * len(df)))
lat_lon_pairs = list(zip(list(sample_df.Start_Lat), list(sample_df.Start_Lng)))

# %%
map = folium.Map()
HeatMap(lat_lon_pairs).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# Ask & answer questions

# %% [markdown]
# 1.Are there more accidents in warmer or colder areas?

# %% [markdown]
# 2.Which 5 states have the highest number of accidents? How about per capita?

# %% [markdown]
# 3.Does New York show up in the data? If yes, why is the count lower if this the most populated city.

# %% [markdown]
# 4.Among the top 100 cities in number of accidents, which states do they belong to most frequently.

# %% [markdown]
# 5.What time of the day are accidents most frequent in? - ANSWERED

# %% [markdown]
# 6.Which days of the week have the most accidents?

# %% [markdown]
# 7.Which months have the most accidents?

# %% [markdown]
# 8.What is the trend of accidents year over year (decreasing/increasing?)

# %% [markdown]
# 9.When is accidents per unit of traffic the highest.

# %% [markdown]
# ## Summary and Conclusion

# %% [markdown]
# 1.No data from New York

# %% [markdown]
#    2.The number of accidents per city decreases exponentially

# %% [markdown]
# 3.Less than 5% of cities have more than 1000 yearly accidents.

# %% [markdown]
# 4.Over 1110 cities have reported just one accident (need to investigate)
